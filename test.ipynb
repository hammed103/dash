# %%
import os
import pandas as pd

# %%
directory = r'C:\Users\SteelSeries\Desktop\Upwork\Alex M\dash\streamlit_navbar-main\data'
file_dataframes = []

# %%
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        file_path = os.path.join(directory, filename)
        df = pd.read_csv(file_path)
        file_dataframes.append(df)

# %%
df = pd.concat(file_dataframes)

# %%
df.to_csv("concat.csv",index=False)

# %%
df1 = df[df.Country == "World"]

# %%
df1["Date"].dt.date
# Out:
# 67       2023-06-19
# 232      2023-06-18
# 496      2023-06-17
# 658      2023-06-16
# 895      2023-06-15
#             ...
# 38565    2022-06-24
# 38723    2022-06-23
# 38750    2022-06-22
# 38841    2022-06-21
# 39054    2022-06-20
# Name: Date, Length: 3650, dtype: object

# %%
df1["Date"] = pd.to_datetime(df1.Date)
# Out:
# C:\Users\SteelSeries\AppData\Local\Temp\ipykernel_23748\2574029894.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Date"] = pd.to_datetime(df1.Date)

# %%
import streamlit as st
from datetime import datetime, timedelta
current_date = datetime.now().date()

# %%
current_date
# Out:
# datetime.date(2023, 6, 23)

# %%
df1.Date.min()
# Out:
# Timestamp('2022-06-20 00:00:00')

# %%
df1.groupby(['Date','ArtistName',"Country"]).sum().sort_values('Date',ascending=False)
# Out:
#                                                       ArtistId  listeners  \
# Date       ArtistName          Country
# 2023-06-19 TWO PUNKS IN LOVE   World    6pOqcPiFkbjIKUBF86cfuM       77.0
#            TEKKNO              World    0aUMVkR8QV0LSdv9VZOATn   258523.0
#            SPED UP DRILL GATES World    4JoVRTzdITLFtxPx72MaQ5     1546.0
#            SICK LEGEND         World    3EYY5FwDkHEYLw5V86SAtl   514267.0
#            RAINY JASPER        World    4rlJtMEpxuem6xZ9DPycFD     3469.0
# ...                                                        ...        ...
# 2022-06-20 SICK LEGEND         World    3EYY5FwDkHEYLw5V86SAtl        0.0
#            SPED UP DRILL GATES World    4JoVRTzdITLFtxPx72MaQ5        0.0
#            TEKKNO              World    0aUMVkR8QV0LSdv9VZOATn        0.0
#            TWO PUNKS IN LOVE   World    6pOqcPiFkbjIKUBF86cfuM        0.0
#            90210               World    4KGcll2G3f04WMGTT19eyz        0.0
#
# ...

# %%
import altair as

# %%
df.Date = pd.to_datetime(df.Date)

# %%
alt.Chart(df).mark_area(
        interpolate="step-after",
    ).encode(
        x=alt.X("Date", scale=alt.Scale(nice=False)),
        y=alt.Y("TEKKNO:Q"),
        tooltip=["Date", "TEKKNO"],
    ).configure_mark(opacity=0.8, color="red").properties(width=800)
# Out:
# alt.Chart(...)

# %%
df
# Out:
#      Total Amount             Date  SICK LEGEND    TEKKNO  HYPERTECHNO  \
# 0         4355558    June 19, 2023    1475275.0  627441.0     146109.0
# 1         3702168    June 18, 2023    1111270.0  497576.0     121115.0
# 2         4058779    June 17, 2023    1300356.0  615061.0     153114.0
# 3         4394572    June 16, 2023    1534782.0  705831.0     172371.0
# 4         4360916    June 15, 2023    1496969.0  650762.0     164541.0
# ..            ...              ...          ...       ...          ...
# 165        120613  January 5, 2023      89521.0   13255.0          0.0
# 166        119704  January 4, 2023      88983.0   13042.0          0.0
# 167        118783  January 3, 2023      88407.0   12840.0          0.0
# 168        117920  January 2, 2023      87904.0   12616.0          0.0
# 169        117002  January 1, 2023      87347.0   12381.0          0.0
#
#      TECHNO N TEQUILLA  DRILL GATES  SPED UP DRILL GATES  11:11 Music Group  \
# ...

# %%
fr = pd.read_csv("Country Demographics Monthly Listeners.csv")

# %%
fr.ArtistName.unique()
# Out:
# array(['DEADBOY', '11:11 Music Group', 'AMBIENT JASPER', 'RAINY JASPER'],
#       dtype=object)
